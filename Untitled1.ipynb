# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iterations = 20000
dice = np.array([1,2,3,4,5,6])
ans = []
count = 0
for i in range(iterations):
 first_roll = np.random.choice(dice) 
 second_roll = np.random.choice(dice)
 sum_roll = first_roll + second_roll
 ans.append(sum_roll)
for value in ans:
    if value > 5:
        count+=1
print('The probability that the sum of two throws is greater than 5 is', count/len(ans))
# Out:
# The probability that the sum of two throws is greater than 5 is 0.7171

# %%
# You can use this cell for your calculations (not graded)
# You can use this cell for your calculations (not graded)
dice = np.array([1,2,3,4])
first_throw = np.array([np.random.choice(dice,p= [1/5,2/5,1/5,1/5])for _ in range(20000)])
second_throw = np.array([np.random.choice(dice,p= [1/5,2/5,1/5,1/5])for _ in range(20000)])
sum_two = first_throw + second_throw
sns.histplot(sum_two,stat = 'probability')
# Out:
# <Axes: ylabel='Probability'>

# %%
# You can use this cell for your calculations (not graded)

dice = np.array([1,2,3,4,5,6])
first_throw = np.array([np.random.choice(dice) for _ in range(20000)])
second_throw = np.array([np.random.choice(dice) for _ in range(20000)])
second_throw =np.where(first_throw<=3,second_throw,0) #only if the first roll is lesser or equal to 3, we roll dice the second time
sum_two = first_throw + second_throw
sns.histplot(sum_two,stat='probability')
# Out:
# <Axes: ylabel='Probability'>

# %%
# You can use this cell for your calculations (not graded)

dice = np.array([1,2,3,4,5,6])
first_throw = np.array([np.random.choice(dice) for _ in range(20000)])
second_throw = np.array([np.random.choice(dice) for _ in range(20000)])
second_throw =np.where(first_throw>=3,second_throw,0) #only if the first roll is lesser or equal to 3, we roll dice the second time
sum_two = first_throw + second_throw
sns.histplot(sum_two,stat='probability')
# Out:
# <Axes: ylabel='Probability'>
